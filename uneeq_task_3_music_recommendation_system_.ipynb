# %% [markdown]
# <a href="https://colab.research.google.com/github/noureldeenhossam/uneeq-internship/blob/main/uneeq_task_3_music_recommendation_system_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/spotify_millsongdata.csv")

# %%
df
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                                     text
# 0      Look at her face, it's a wonderful face  \r\nA...
# 1      Take it easy with me, please  \r\nTouch me gen...
# 2      I'll never know why I had to go  \r\nWhy I had...
# 3      Making somebody happy is a question of give an...
# 4      Making somebody happy is a question of give an...
# ...                                                  ...
# ...

# %%
df.head()
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.drop("link",axis=1,inplace=True)

# %%
df.head()
# Out:
#   artist                   song  \
# 0   ABBA  Ahe's My Kind Of Girl
# 1   ABBA       Andante, Andante
# 2   ABBA         As Good As New
# 3   ABBA                   Bang
# 4   ABBA       Bang-A-Boomerang
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# text      0
# dtype: int64

# %%
df['text'][5]
# Out:
# "Well, you hoot and you holler and you make me mad  \r\nAnd I've always been under your heel  \r\nHoly christ what a lousy deal  \r\nNow I'm sick and tired of your tedious ways  \r\nAnd I ain't gonna take it no more  \r\nOh no no - walkin' out that door  \r\n  \r\nBurning my bridges, cutting my tie  \r\nOnce again I wanna look into the eye  \r\nBeing myself  \r\nCounting my pride  \r\nNo un-right neighbour's gonna take me for a ride  \r\nBurning my bridges  \r\nMoving at last  \r\nGirl I'm leaving and I'm burying the past  \r\nGonna have peace now  \r\nYou can be free  \r\nNo one here will make a sucker out of me\r\n\r\n"

# %%
df.shape
# Out:
# (57650, 3)

# %%
df
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                                     text
# 0      Look at her face, it's a wonderful face  \r\nA...
# 1      Take it easy with me, please  \r\nTouch me gen...
# 2      I'll never know why I had to go  \r\nWhy I had...
# 3      Making somebody happy is a question of give an...
# 4      Making somebody happy is a question of give an...
# ...                                                  ...
# ...

# %%
#text processing

# %%
df =df.sample(5000)

# %%
df.head(20
        )
# Out:
#                    artist                                 song  \
# 37217       Irving Berlin                        Easter Parade
# 38261          John Prine                              Bad Boy
# 11623      Linda Ronstadt                     I Fall To Pieces
# 4083         Depeche Mode                      All That's Mine
# 12847           Metallica                         The Mechanix
# 39188       Justin Bieber                 Someday At Christmas
# 3474       Counting Crows                      A Murder Of One
# 53811    Townes Van Zandt                           Snake Song
# 40718                Kiss                                  She
# 40236         The Killers  Why Don't You Find Out For Yourself
# 6645      George Harrison                            This Song
# 38406          John Waite               Straight To Your Heart
# 18463       Savage Garden             I Don't Know You Anymore
# 16678          Quietdrive                         Take A Drink
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df['text'] = df['text'].str.lower().replace(r'^\w\s', ' ').replace(r'\n', ' ', regex = True)

# %%
# !pip install nltk
import nltk
nltk.download('punkt')

import nltk
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

def tokenization(txt):
    tokens = nltk.word_tokenize(txt)
    stemming = [stemmer.stem(w) for w in tokens]
    return " ".join(stemming)

df['text'] = df['text'].apply(lambda x: tokenization(x))
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Combine text features into a single column
df['combined_features'] = df['artist'] + ' ' + df['song'] + ' ' + df['text']

# Initialize the TF-IDF Vectorizer
tfidf_vectorizer = TfidfVectorizer(max_features=50000)

# Fit and transform the combined text data
tfidf_matrix = tfidf_vectorizer.fit_transform(df['combined_features'])

# Convert TF-IDF matrix to a DataFrame
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), index=df.index)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Compute the cosine similarity matrix
cosine_sim_matrix = cosine_similarity(tfidf_matrix)

def recommend_songs(song_title, cosine_sim_matrix, df, top_n=10):
    # Get the index of the song that matches the title
    song_idx = df[df['song'].str.contains(song_title, case=False)].index[0]

    # Get the pairwise similarity scores of all songs with that song
    sim_scores = list(enumerate(cosine_sim_matrix[song_idx]))

    # Sort the songs based on similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the indices of the top_n most similar songs
    sim_scores = sim_scores[1:top_n+1]

    # Get the titles of the most similar songs
    song_indices = [i[0] for i in sim_scores]

    return df[['artist', 'song']].iloc[song_indices]

# %%
recommendations = recommend_songs("she", cosine_sim_matrix, df, top_n=10)
print(recommendations)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-63-293b9ec8cbd5> in <cell line: 1>()
# ----> 1 recommendations = recommend_songs("she", cosine_sim_matrix, df, top_n=10)
#       2 print(recommendations)
#
# <ipython-input-60-f468f981a34e> in recommend_songs(song_title, cosine_sim_matrix, df, top_n)
#       9
#      10     # Get the pairwise similarity scores of all songs with that song
# ---> 11     sim_scores = list(enumerate(cosine_sim_matrix[song_idx]))
#      12
#      13     # Sort the songs based on similarity scores
#
# IndexError: index 40718 is out of bounds for axis 0 with size 5000

# %%
print(tfidf_matrix.shape)
# Out:
# (5000, 24787)
